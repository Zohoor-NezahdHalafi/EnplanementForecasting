# %% [markdown]
# # ARIMA Orders
#
# The purpose of this notebook is to set the optimal ARIMA order for each series. This order will inform other decisions in the modeling process. We use a training set of 70% and the auto-arima process from the pmdarima package to set the order of each series. After we have the order, we save the results to a pickle object that will be read in in subsequent notebooks.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima import auto_arima
import os
import warnings
import pickle
from config import train_prop

warnings.filterwarnings('ignore')
sns.set(rc={'figure.figsize':(14,7)})

# %% [markdown]
# Create a dictionary of dictionaries where the key is each file name that we saved to csv files in the subsequent notebook and the value is an empty dictionary. This will be filled in later with the orders.

# %%
series_map = {
    'IAH-Dom':{},
    'IAH-Int':{},
    'HOU-Dom':{},
    'HOU-Int':{},
}

# %%
def find_orders(series,alpha=0.05):
    """ finds the optimal ARIMA order of the prepared time series data using the auto_arima function from pmdarima
    
    Args:
        series (str): the name of the series saved as a csv file in the data directory (without the .csv at the end).
        alpha (float): the critical pval to reject the null hypothesis in the auto_arima process.
        
    Returns:
        None
    """
    print(f'finding order for {series}')
    df = pd.read_csv(os.path.join('data',series+'.csv'),parse_dates=['Date'],index_col=0)
    train = df.iloc[:int(train_prop*(df.shape[0])),:]
    auto_model = auto_arima(train,start_P=1,start_q=1,max_p=6,max_q=6,m=12,seasonal=True,max_P=2, max_D=2,max_Q=2,
                            max_d=2,trace=True,error_action='ignore',suppress_warnings=True,stepwise=True,information_criterion="aic",alpha=alpha,scoring='mse')
    best_params = auto_model.get_params()
    series_map[series]['order'] = best_params['order']
    series_map[series]['seasonal_order'] = best_params['seasonal_order']
    series_map[series]['trend'] = best_params['trend']

def test_arima_model_validity(series,critical_pval=0.05):
    """ fits the model with the order found in the find_orders() function and runs the following tests:
    checks if all pvalues are below the critical_pval to determine if model is parsimonious
    runs the Jarque-Bera test to determine if standard residuals are normally distributed
    *runs the Ljung-Box test of autocorrelation in residuals to determine if the model is valid
    Tests for heteroskedasticity of standardized residuals
    Results of all tests are printed to console.
    SARIMA model summary is printed to console.
    Plots model diagnostics using matplotlib.
    See more about how the tests were performed: https://www.statsmodels.org/devel/generated/statsmodels.tsa.arima.model.ARIMAResults.html
    
    Args:
        series (str): the name of the series saved as a csv file in the data directory (without the .csv at the end).
        critical_pval (float): the critical pval to reject the null hypothesis for all performed statistical tests.
        
    Returns:
        None
    """
    df = pd.read_csv(os.path.join('data',series+'.csv'),parse_dates=['Date'],index_col=0)
    train = df.iloc[:int(train_prop*(df.shape[0])),:]
    order = series_map[series]['order']
    seasonal_order = series_map[series]['seasonal_order']
    trend = series_map[series]['trend']
    
    print(f'{series} order: {order} x {seasonal_order}')
    print('-'*120)
    
    iter_me = {'train':train,'full':df}
    for t, d in iter_me.items():
        model = SARIMAX(d,
                        order=order,
                        seasonal_order=seasonal_order,
                        trend=trend)
        results = model.fit()
        print('{} {} model is {}'.format(series,t,'parsimonious' if max(results.pvalues) <= critical_pval else 'not parsimonious'))
        print('{} {} model {} normally distributed errors'.format(series,t,'has' if results.test_normality('jarquebera')[0][1] > critical_pval else 'does not have'))
        #print('{} {} model is {}'.format(series,t,'valid' if sm.stats.acorr_ljungbox(results.resid, auto_lag = True, return_df=True)['bpvalue'].min() > critical_pval else 'not valid'))
        print('{} {} model errors are {}'.format(series,t,'homoskedastic' if results.test_heteroskedasticity('breakvar')[0][1] > critical_pval else 'heteroskedastic'))
        print(results.summary())
        results.plot_diagnostics()
        plt.show()
        print('='*120)
        print('='*120)

# %% [markdown]
# This is how we assign ARIMA orders.

# %%
for series in series_map.keys():
    find_orders(series)
# Out:
# finding order for IAH-Dom
# Performing stepwise search to minimize aic
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.43 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=4579.010, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=4489.993, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=4506.196, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=4577.040, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=4563.474, Time=0.03 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=4488.645, Time=0.24 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=4485.316, Time=0.30 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=4483.434, Time=0.14 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=4510.032, Time=0.06 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=4485.052, Time=0.48 sec
#  ARIMA(1,1,0)(0,0,2)[12] intercept   : AIC=4499.722, Time=0.16 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=4486.261, Time=0.57 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=4497.981, Time=0.08 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=4480.310, Time=0.19 sec
#  ARIMA(2,1,0)(0,0,1)[12] intercept   : AIC=4509.050, Time=0.07 sec
#  ARIMA(2,1,0)(1,0,0)[12] intercept   : AIC=4488.084, Time=0.10 sec
#  ARIMA(2,1,0)(2,0,1)[12] intercept   : AIC=4482.074, Time=0.32 sec
#  ARIMA(2,1,0)(1,0,2)[12] intercept   : AIC=4481.832, Time=0.74 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=4564.534, Time=0.04 sec
#  ARIMA(2,1,0)(0,0,2)[12] intercept   : AIC=4498.151, Time=0.29 sec
#  ARIMA(2,1,0)(2,0,0)[12] intercept   : AIC=4486.591, Time=0.39 sec
#  ARIMA(2,1,0)(2,0,2)[12] intercept   : AIC=4483.382, Time=0.69 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=4480.315, Time=0.26 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=4478.815, Time=0.36 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=4505.573, Time=0.16 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=4486.561, Time=0.22 sec
#  ARIMA(1,1,1)(2,0,1)[12] intercept   : AIC=4480.601, Time=0.63 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=4480.351, Time=0.62 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=4554.992, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,2)[12] intercept   : AIC=4495.376, Time=0.51 sec
#  ARIMA(1,1,1)(2,0,0)[12] intercept   : AIC=4485.036, Time=0.50 sec
#  ARIMA(1,1,1)(2,0,2)[12] intercept   : AIC=4481.816, Time=0.53 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=4477.854, Time=0.14 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=4485.429, Time=0.09 sec
#  ARIMA(0,1,1)(2,0,1)[12] intercept   : AIC=4479.663, Time=0.30 sec
#  ARIMA(0,1,1)(1,0,2)[12] intercept   : AIC=4479.390, Time=0.63 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=4561.417, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,2)[12] intercept   : AIC=4495.365, Time=0.28 sec
#  ARIMA(0,1,1)(2,0,0)[12] intercept   : AIC=4483.999, Time=0.23 sec
#  ARIMA(0,1,1)(2,0,2)[12] intercept   : AIC=4480.786, Time=0.51 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=4470.013, Time=0.16 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=4503.578, Time=0.08 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=4480.060, Time=0.09 sec
#  ARIMA(0,1,2)(2,0,1)[12] intercept   : AIC=4471.539, Time=0.44 sec
#  ARIMA(0,1,2)(1,0,2)[12] intercept   : AIC=4471.367, Time=0.81 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=4565.619, Time=0.05 sec
#  ARIMA(0,1,2)(0,0,2)[12] intercept   : AIC=4491.100, Time=0.21 sec
#  ARIMA(0,1,2)(2,0,0)[12] intercept   : AIC=4478.150, Time=0.31 sec
#  ARIMA(0,1,2)(2,0,2)[12] intercept   : AIC=4473.208, Time=0.58 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=4462.069, Time=0.28 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=4502.003, Time=0.17 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=4474.147, Time=0.17 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=inf, Time=0.98 sec
#  ARIMA(1,1,2)(1,0,2)[12] intercept   : AIC=inf, Time=1.09 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=4563.241, Time=0.16 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=4486.840, Time=0.34 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=4471.635, Time=0.51 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=4465.115, Time=0.65 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=4447.701, Time=0.69 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=4498.775, Time=0.23 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=4467.821, Time=0.30 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=4447.300, Time=1.34 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=4465.100, Time=1.00 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=4449.985, Time=1.38 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=4446.946, Time=1.23 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=4480.611, Time=0.63 sec
#  ARIMA(2,1,1)(1,0,2)[12] intercept   : AIC=inf, Time=0.89 sec
#  ARIMA(3,1,2)(1,0,2)[12] intercept   : AIC=4452.329, Time=1.48 sec
#  ARIMA(2,1,3)(1,0,2)[12] intercept   : AIC=4459.850, Time=1.64 sec
#  ARIMA(1,1,3)(1,0,2)[12] intercept   : AIC=inf, Time=1.15 sec
#  ARIMA(3,1,1)(1,0,2)[12] intercept   : AIC=inf, Time=1.06 sec
#  ARIMA(3,1,3)(1,0,2)[12] intercept   : AIC=4459.317, Time=2.17 sec
#  ARIMA(2,1,2)(1,0,2)[12]             : AIC=4451.849, Time=1.41 sec
#
# Best model:  ARIMA(2,1,2)(1,0,2)[12] intercept
# Total fit time: 35.357 seconds
# finding order for IAH-Int
# Performing stepwise search to minimize aic
#  ARIMA(2,0,1)(1,1,1)[12] intercept   : AIC=3637.828, Time=0.49 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=3671.263, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=3651.562, Time=0.21 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=3640.358, Time=0.15 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=3727.671, Time=0.02 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=3637.223, Time=0.34 sec
#  ARIMA(2,0,1)(0,1,0)[12] intercept   : AIC=3673.014, Time=0.24 sec
#  ARIMA(2,0,1)(0,1,2)[12] intercept   : AIC=3637.174, Time=1.12 sec
#  ARIMA(2,0,1)(1,1,2)[12] intercept   : AIC=inf, Time=3.10 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=3640.294, Time=0.66 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=3655.348, Time=0.57 sec
#  ARIMA(3,0,1)(0,1,2)[12] intercept   : AIC=3637.067, Time=1.29 sec
#  ARIMA(3,0,1)(0,1,1)[12] intercept   : AIC=3637.635, Time=0.51 sec
#  ARIMA(3,0,1)(1,1,2)[12] intercept   : AIC=3638.213, Time=1.99 sec
#  ARIMA(3,0,1)(1,1,1)[12] intercept   : AIC=3638.402, Time=0.82 sec
#  ARIMA(3,0,0)(0,1,2)[12] intercept   : AIC=3657.148, Time=0.64 sec
#  ARIMA(4,0,1)(0,1,2)[12] intercept   : AIC=3632.482, Time=1.35 sec
#  ARIMA(4,0,1)(0,1,1)[12] intercept   : AIC=3634.006, Time=0.51 sec
#  ARIMA(4,0,1)(1,1,2)[12] intercept   : AIC=3632.889, Time=2.00 sec
#  ARIMA(4,0,1)(1,1,1)[12] intercept   : AIC=3634.201, Time=0.57 sec
#  ARIMA(4,0,0)(0,1,2)[12] intercept   : AIC=3656.086, Time=0.60 sec
#  ARIMA(5,0,1)(0,1,2)[12] intercept   : AIC=3634.013, Time=1.38 sec
#  ARIMA(4,0,2)(0,1,2)[12] intercept   : AIC=3628.325, Time=3.28 sec
#  ARIMA(4,0,2)(0,1,1)[12] intercept   : AIC=3630.979, Time=1.22 sec
#  ARIMA(4,0,2)(1,1,2)[12] intercept   : AIC=inf, Time=3.65 sec
#  ARIMA(4,0,2)(1,1,1)[12] intercept   : AIC=3631.736, Time=1.34 sec
#  ARIMA(3,0,2)(0,1,2)[12] intercept   : AIC=inf, Time=2.65 sec
#  ARIMA(5,0,2)(0,1,2)[12] intercept   : AIC=3630.209, Time=2.71 sec
#  ARIMA(4,0,3)(0,1,2)[12] intercept   : AIC=inf, Time=3.37 sec
#  ARIMA(3,0,3)(0,1,2)[12] intercept   : AIC=3649.896, Time=3.28 sec
#  ARIMA(5,0,3)(0,1,2)[12] intercept   : AIC=inf, Time=4.39 sec
#  ARIMA(4,0,2)(0,1,2)[12]             : AIC=3683.034, Time=2.86 sec
#
# Best model:  ARIMA(4,0,2)(0,1,2)[12] intercept
# Total fit time: 47.375 seconds
# finding order for HOU-Dom
# Performing stepwise search to minimize aic
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=4189.922, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=4108.629, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=4124.485, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=4188.061, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=4179.541, Time=0.02 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=4107.032, Time=0.22 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=4105.595, Time=0.54 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=4103.596, Time=0.28 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=4128.509, Time=0.05 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=4105.360, Time=0.39 sec
#  ARIMA(1,1,0)(0,0,2)[12] intercept   : AIC=4119.150, Time=0.18 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=0.69 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=4113.782, Time=0.18 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=4099.962, Time=0.23 sec
#  ARIMA(2,1,0)(0,0,1)[12] intercept   : AIC=4126.667, Time=0.07 sec
#  ARIMA(2,1,0)(1,0,0)[12] intercept   : AIC=4105.916, Time=0.08 sec
#  ARIMA(2,1,0)(2,0,1)[12] intercept   : AIC=4101.949, Time=0.53 sec
#  ARIMA(2,1,0)(1,0,2)[12] intercept   : AIC=4101.666, Time=0.48 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=4179.954, Time=0.04 sec
#  ARIMA(2,1,0)(0,0,2)[12] intercept   : AIC=4117.002, Time=0.21 sec
#  ARIMA(2,1,0)(2,0,0)[12] intercept   : AIC=4104.170, Time=0.32 sec
#  ARIMA(2,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=0.85 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=4100.874, Time=0.38 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=4100.044, Time=0.36 sec
#  ARIMA(3,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.55 sec
#  ARIMA(2,1,0)(1,0,1)[12]             : AIC=4094.413, Time=0.23 sec
#  ARIMA(2,1,0)(0,0,1)[12]             : AIC=4124.842, Time=0.06 sec
#  ARIMA(2,1,0)(1,0,0)[12]             : AIC=4103.805, Time=0.08 sec
#  ARIMA(2,1,0)(2,0,1)[12]             : AIC=4095.908, Time=0.57 sec
#  ARIMA(2,1,0)(1,0,2)[12]             : AIC=4095.808, Time=0.54 sec
#  ARIMA(2,1,0)(0,0,0)[12]             : AIC=4178.367, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,2)[12]             : AIC=4115.120, Time=0.20 sec
#  ARIMA(2,1,0)(2,0,0)[12]             : AIC=4101.944, Time=0.29 sec
#  ARIMA(2,1,0)(2,0,2)[12]             : AIC=4097.725, Time=0.44 sec
#  ARIMA(1,1,0)(1,0,1)[12]             : AIC=4097.750, Time=0.24 sec
#  ARIMA(3,1,0)(1,0,1)[12]             : AIC=4094.804, Time=0.33 sec
#  ARIMA(2,1,1)(1,0,1)[12]             : AIC=4091.872, Time=0.37 sec
#  ARIMA(2,1,1)(0,0,1)[12]             : AIC=4119.217, Time=0.15 sec
#  ARIMA(2,1,1)(1,0,0)[12]             : AIC=4099.931, Time=0.16 sec
#  ARIMA(2,1,1)(2,0,1)[12]             : AIC=4093.226, Time=1.09 sec
#  ARIMA(2,1,1)(1,0,2)[12]             : AIC=4093.116, Time=1.01 sec
#  ARIMA(2,1,1)(0,0,0)[12]             : AIC=4167.586, Time=0.08 sec
#  ARIMA(2,1,1)(0,0,2)[12]             : AIC=4110.648, Time=0.37 sec
#  ARIMA(2,1,1)(2,0,0)[12]             : AIC=4098.577, Time=0.57 sec
#  ARIMA(2,1,1)(2,0,2)[12]             : AIC=4095.059, Time=1.04 sec
#  ARIMA(1,1,1)(1,0,1)[12]             : AIC=4090.939, Time=0.35 sec
#  ARIMA(1,1,1)(0,0,1)[12]             : AIC=4117.985, Time=0.11 sec
#  ARIMA(1,1,1)(1,0,0)[12]             : AIC=4099.014, Time=0.14 sec
#  ARIMA(1,1,1)(2,0,1)[12]             : AIC=4092.216, Time=0.84 sec
#  ARIMA(1,1,1)(1,0,2)[12]             : AIC=4092.094, Time=0.62 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=4165.946, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,2)[12]             : AIC=4109.518, Time=0.29 sec
#  ARIMA(1,1,1)(2,0,0)[12]             : AIC=4097.836, Time=0.37 sec
#  ARIMA(1,1,1)(2,0,2)[12]             : AIC=4094.041, Time=0.73 sec
#  ARIMA(0,1,1)(1,0,1)[12]             : AIC=4092.757, Time=0.22 sec
#  ARIMA(1,1,2)(1,0,1)[12]             : AIC=4080.305, Time=0.57 sec
#  ARIMA(1,1,2)(0,0,1)[12]             : AIC=4112.728, Time=0.23 sec
#  ARIMA(1,1,2)(1,0,0)[12]             : AIC=4090.184, Time=0.24 sec
#  ARIMA(1,1,2)(2,0,1)[12]             : AIC=4081.576, Time=1.12 sec
#  ARIMA(1,1,2)(1,0,2)[12]             : AIC=4081.441, Time=0.90 sec
#  ARIMA(1,1,2)(0,0,0)[12]             : AIC=4169.864, Time=0.13 sec
#  ARIMA(1,1,2)(0,0,2)[12]             : AIC=4102.408, Time=0.60 sec
#  ARIMA(1,1,2)(2,0,0)[12]             : AIC=4088.340, Time=0.65 sec
#  ARIMA(1,1,2)(2,0,2)[12]             : AIC=4083.361, Time=1.49 sec
#  ARIMA(0,1,2)(1,0,1)[12]             : AIC=4086.105, Time=0.51 sec
#  ARIMA(2,1,2)(1,0,1)[12]             : AIC=inf, Time=0.47 sec
#  ARIMA(1,1,3)(1,0,1)[12]             : AIC=inf, Time=0.67 sec
#  ARIMA(0,1,3)(1,0,1)[12]             : AIC=4090.571, Time=0.36 sec
#  ARIMA(2,1,3)(1,0,1)[12]             : AIC=inf, Time=0.51 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.36 sec
#
# Best model:  ARIMA(1,1,2)(1,0,1)[12]
# Total fit time: 27.712 seconds
# finding order for HOU-Int
# Performing stepwise search to minimize aic
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=672.300, Time=0.14 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=665.958, Time=0.07 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=666.881, Time=0.04 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=667.153, Time=0.05 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=665.627, Time=0.04 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=668.248, Time=0.07 sec
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=667.178, Time=0.12 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=665.181, Time=0.03 sec
#  ARIMA(0,1,0)(0,1,2)[12]             : AIC=667.172, Time=0.07 sec
#  ARIMA(0,1,0)(1,1,2)[12]             : AIC=669.175, Time=0.09 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=666.786, Time=0.04 sec
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=668.540, Time=0.12 sec
#  ARIMA(0,1,0)(0,1,1)[12] intercept   : AIC=666.617, Time=0.04 sec
#
# Best model:  ARIMA(0,1,0)(0,1,1)[12]
# Total fit time: 0.941 seconds

# %% [markdown]
# Write out pickled results that will be read in the other notebooks.

# %%
with open('pickled/series_map.pckl','wb') as f:
    pickle.dump(series_map,f)
    
with open('pickled/train_prop.pckl','wb') as f:
    pickle.dump(train_prop,f)

# %% [markdown]
# This is how we test the statistical validity of our derived models.

# %%
for series in series_map.keys():
    test_arima_model_validity(series)
# Out:
# IAH-Dom order: (2, 1, 2) x (1, 0, 2, 12)
# ------------------------------------------------------------------------------------------------------------------------
# IAH-Dom train model is not parsimonious
# IAH-Dom train model does not have normally distributed errors
# IAH-Dom train model errors are heteroskedastic
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                         PASSENGERS   No. Observations:                  174
# Model:             SARIMAX(2, 1, 2)x(1, 0, 2, 12)   Log Likelihood               -2217.925
# Date:                            Wed, 09 Mar 2022   AIC                           4451.849
# Time:                                    16:25:16   BIC                           4477.075
# Sample:                                01-01-2001   HQIC                          4462.083
#                                      - 06-01-2015
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8184      0.244      3.359      0.001       0.341       1.296
# ar.L2          0.0891      0.168      0.531      0.595      -0.239       0.418
# ma.L1         -1.0707      0.230     -4.652      0.000      -1.522      -0.620
# ma.L2          0.1062      0.191      0.557      0.577      -0.267       0.480
# ar.S.L12       0.9263      0.043     21.477      0.000       0.842       1.011
# ma.S.L12      -0.6577      0.064    -10.298      0.000      -0.783      -0.533
# ma.S.L24      -0.0864      0.043     -2.018      0.044      -0.170      -0.002
# sigma2      8.888e+09   8.29e-11   1.07e+20      0.000    8.89e+09    8.89e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.18   Jarque-Bera (JB):               553.06
# Prob(Q):                              0.07   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.11   Skew:                            -1.69
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.08
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.77e+35. Standard errors may be unstable.
# ========================================================================================================================
# ========================================================================================================================
# IAH-Dom full model is not parsimonious
# IAH-Dom full model does not have normally distributed errors
# IAH-Dom full model errors are homoskedastic
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                         PASSENGERS   No. Observations:                  249
# Model:             SARIMAX(2, 1, 2)x(1, 0, 2, 12)   Log Likelihood               -3226.275
# Date:                            Wed, 09 Mar 2022   AIC                           6468.550
# Time:                                    16:25:18   BIC                           6496.658
# Sample:                                01-01-2001   HQIC                          6479.865
#                                      - 09-01-2021
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0148      0.048     -0.309      0.757      -0.109       0.079
# ar.L2          0.9021      0.046     19.734      0.000       0.813       0.992
# ma.L1          0.0035      0.099      0.035      0.972      -0.191       0.198
# ma.L2         -0.9961      0.069    -14.386      0.000      -1.132      -0.860
# ar.S.L12       0.9486      0.033     28.822      0.000       0.884       1.013
# ma.S.L12      -0.8979      0.071    -12.716      0.000      -1.036      -0.759
# ma.S.L24       0.1152      0.049      2.362      0.018       0.020       0.211
# sigma2      1.574e+10   1.11e-11   1.41e+21      0.000    1.57e+10    1.57e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.53   Jarque-Bera (JB):              2482.41
# Prob(Q):                              0.47   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.12   Skew:                            -2.58
# Prob(H) (two-sided):                  0.60   Kurtosis:                        17.61
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.29e+36. Standard errors may be unstable.
# ========================================================================================================================
# ========================================================================================================================
# IAH-Int order: (4, 0, 2) x (0, 1, 2, 12)
# ------------------------------------------------------------------------------------------------------------------------
# IAH-Int train model is not parsimonious
# IAH-Int train model does not have normally distributed errors
# IAH-Int train model errors are heteroskedastic
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                         PASSENGERS   No. Observations:                  174
# Model:             SARIMAX(4, 0, 2)x(0, 1, 2, 12)   Log Likelihood               -1832.517
# Date:                            Wed, 09 Mar 2022   AIC                           3683.034
# Time:                                    16:25:22   BIC                           3710.822
# Sample:                                01-01-2001   HQIC                          3694.316
#                                      - 06-01-2015
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.5492      0.102     15.158      0.000       1.349       1.749
# ar.L2         -0.9729      0.144     -6.741      0.000      -1.256      -0.690
# ar.L3          0.1913      0.084      2.266      0.023       0.026       0.357
# ar.L4          0.0132      0.059      0.222      0.824      -0.103       0.130
# ma.L1         -1.2174      0.104    -11.746      0.000      -1.421      -1.014
# ma.L2          0.7408      0.120      6.195      0.000       0.506       0.975
# ma.S.L12      -0.1744      0.033     -5.327      0.000      -0.239      -0.110
# ma.S.L24       0.0567      0.029      1.927      0.054      -0.001       0.114
# sigma2      2.327e+08   5.44e-10   4.28e+17      0.000    2.33e+08    2.33e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   4.39   Jarque-Bera (JB):               532.31
# Prob(Q):                              0.04   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.38   Skew:                            -1.66
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.98e+33. Standard errors may be unstable.
# ========================================================================================================================
# ========================================================================================================================
# IAH-Int full model is not parsimonious
# IAH-Int full model does not have normally distributed errors
# IAH-Int full model errors are heteroskedastic
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                         PASSENGERS   No. Observations:                  249
# Model:             SARIMAX(4, 0, 2)x(0, 1, 2, 12)   Log Likelihood               -2804.146
# Date:                            Wed, 09 Mar 2022   AIC                           5626.291
# Time:                                    16:25:25   BIC                           5657.504
# Sample:                                01-01-2001   HQIC                          5638.872
#                                      - 09-01-2021
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.2883      0.417      3.087      0.002       0.470       2.106
# ar.L2         -1.0229      0.540     -1.894      0.058      -2.081       0.036
# ar.L3          0.7444      0.260      2.863      0.004       0.235       1.254
# ar.L4         -0.1541      0.075     -2.043      0.041      -0.302      -0.006
# ma.L1         -0.2470      0.409     -0.604      0.546      -1.048       0.554
# ma.L2          0.6983      0.233      2.995      0.003       0.241       1.155
# ma.S.L12      -0.7483      0.059    -12.628      0.000      -0.864      -0.632
# ma.S.L24       0.1558      0.060      2.580      0.010       0.037       0.274
# sigma2      1.216e+09   5.89e-09   2.07e+17      0.000    1.22e+09    1.22e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.72   Jarque-Bera (JB):              4709.97
# Prob(Q):                              0.19   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.95   Skew:                            -3.26
# Prob(H) (two-sided):                  0.00   Kurtosis:                        23.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.78e+32. Standard errors may be unstable.
# ========================================================================================================================
# ========================================================================================================================
# HOU-Dom order: (1, 1, 2) x (1, 0, 1, 12)
# ------------------------------------------------------------------------------------------------------------------------
# HOU-Dom train model is not parsimonious
# HOU-Dom train model does not have normally distributed errors
# HOU-Dom train model errors are heteroskedastic
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                           PASSENGERS   No. Observations:                  174
# Model:             SARIMAX(1, 1, 2)x(1, 0, [1], 12)   Log Likelihood               -2034.152
# Date:                              Wed, 09 Mar 2022   AIC                           4080.305
# Time:                                      16:25:27   BIC                           4099.225
# Sample:                                  01-01-2001   HQIC                          4087.980
#                                        - 06-01-2015
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7820      0.152      5.146      0.000       0.484       1.080
# ma.L1         -1.0930      0.149     -7.315      0.000      -1.386      -0.800
# ma.L2          0.1380      0.102      1.351      0.177      -0.062       0.338
# ar.S.L12       0.9249      0.050     18.639      0.000       0.828       1.022
# ma.S.L12      -0.7221      0.098     -7.387      0.000      -0.914      -0.531
# sigma2      1.383e+09   6.13e-11   2.26e+19      0.000    1.38e+09    1.38e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.58   Jarque-Bera (JB):               170.07
# Prob(Q):                              0.21   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.28   Skew:                            -1.01
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.76e+35. Standard errors may be unstable.
# ========================================================================================================================
# ========================================================================================================================
